# %%
import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np

# %%
df1 = pd.read_csv("LOL_items_stats.csv", encoding='utf-8', delimiter=';')
df1
# Out:
#                     Item  Cost    Sell    AD    AS  Crit  LS  APen    AP  \
# 0           Abyssal Mask  2700  1890.0   NaN   NaN   NaN NaN   NaN   NaN
# 1    Aegis of the Legion  1500  1050.0   NaN   NaN   NaN NaN   NaN   NaN
# 2            Aether Wisp   850   595.0   NaN   NaN   NaN NaN   NaN  30.0
# 3        Amplifying Tome   435   304.5   NaN   NaN   NaN NaN   NaN  20.0
# 4      Archangel's Staff  3000  2100.0   NaN   NaN   NaN NaN   NaN  65.0
# ..                   ...   ...     ...   ...   ...   ...  ..   ...   ...
# 189                 Zeal  1050   735.0   NaN  0.18  0.15 NaN   NaN   NaN
# 190   Zeke's Convergence  2400  1680.0   NaN   NaN   NaN NaN   NaN   NaN
# 191   Zhonya's Hourglass  2600  1820.0   NaN   NaN   NaN NaN   NaN  65.0
# 192    Anathema's Chains  2500  1750.0   NaN   NaN   NaN NaN   NaN   NaN
# 193          Hullbreaker  2800  1960.0  50.0   NaN   NaN NaN   NaN   NaN
#
#        AH  ...  MP5  HSP  OVamp  MPen  Health  Armor    MR   HP5  MS  Maps
# ...

# %%
file = "LOL_champions_stats.csv"
# df2 = df2 = pd.read_csv(file)
df2 = pd.read_csv(file,encoding='ISO-8859-1', delimiter=';')
df2.head()
# Out:
#   champion_name       champion_title    class   playstyle date_release  \
# 0        Aatrox     the Darkin Blade  Fighter  Juggernaut   13/06/2013
# 1          Ahri  the Nine-Tailed Fox     Mage       Burst   14/12/2011
# 2         Akali   the Rogue Assassin   Slayer    Assassin   11/05/2010
# 3       Alistar         the Minotaur     Tank    Vanguard   21/02/2009
# 4         Amumu        the Sad Mummy     Tank    Vanguard   26/06/2009
#
#   last_change  blue_essence_price  rp_price   ressource     HP  ...    AR  \
# 0       V11.2                4800       880  Blood Well  580.0  ...  38.0
# 1       V11.1                3150       790        Mana  526.0  ...  21.0
# 2      V11.10                3150       790      Energy  500.0  ...  23.0
# 3       V11.8                1350       585        Mana  600.0  ...  44.0
# 4       V11.7                 450       260        Mana  615.0  ...  30.0
#
#     AR+  AR_lvl18    MR   MR+  MR_lvl18   MS  MS_lvl18  range  range_lvl18
# ...

# %%
import chardet
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
file = "/content/lol_champion_stats_en.csv"
# df3 = pd.read_csv(file)
df3 = pd.read_csv(file,encoding='ISO-8859-1', delimiter=';')
df3

# %%
# file1 = "/content/LOL_items_stats.csv"
# file2 = "/content/lol_champion_stats_en.csv"
df1 = spark.read.csv(file1,encoding='ISO-8859-1', header=True, sep =';')
# df1 = pd.read_csv(file1,encoding='ISO-8859-1', delimiter=';')
# df2 = pd.read_csv(file2,encoding='ISO-8859-1', delimiter=';')
# df1.show()

# %%
df2 = pd.read_csv("LOL_champions_stats.csv", encoding='utf-8', delimiter=';')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29676\1428243781.py in <module>
# ----> 1 df2 = pd.read_csv("LOL_champions_stats.csv", encoding='utf-8', delimiter=';')
#
# c:\Users\MD_Rahman\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df3 = pd.read_csv("lol_champion_stats_en.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29676\323352628.py in <module>
# ----> 1 df3 = pd.read_csv("lol_champion_stats_en.csv")
#
# c:\Users\MD_Rahman\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
